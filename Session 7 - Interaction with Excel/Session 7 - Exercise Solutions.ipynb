# %% [markdown]
# # 7. Exercise Solutions

# %%
import xlwings as xw


wb = xw.Book('Session 7 - Exercise Solutions.xlsx')

sht1 = wb.sheets['Sheet1']
sht2 = wb.sheets['Sheet2']

# %%
import numpy as np

sht1.range('A1').options(transpose=True).value = np.arange(-50, 51, 5)

# %%
import pandas as pd

df_raw = pd.read_csv('Sydney_weather.csv')

df_raw.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-02-01   Sydney     19.5     22.4      15.6          6.2       0.0
# 1  2008-02-02   Sydney     19.5     25.6       6.0          3.4       2.7
# 2  2008-02-03   Sydney     21.6     24.5       6.6          2.4       0.1
# 3  2008-02-04   Sydney     20.2     22.8      18.8          2.2       0.0
# 4  2008-02-05   Sydney     19.7     25.7      77.4          NaN       0.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0         NaN            NaN          S  ...        84.0       1017.6
# 1         NaN            NaN          W  ...        73.0       1017.9
# 2         NaN            NaN        ESE  ...        86.0       1016.7
# 3         NaN            NaN        NNE  ...        90.0       1014.2
# 4         NaN            NaN        NNE  ...        74.0       1008.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df_raw['Date'] = pd.to_datetime(df_raw['Date'])

# %%
df = df_raw.set_index('Date')

df.tail()
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# Date
# 2017-06-21   Sydney      8.6     19.6       0.0          2.0       7.8
# 2017-06-22   Sydney      9.3     19.2       0.0          2.0       9.2
# 2017-06-23   Sydney      9.4     17.7       0.0          2.4       2.7
# 2017-06-24   Sydney     10.1     19.3       0.0          1.4       9.3
# 2017-06-25   Sydney      7.6     19.3       0.0          3.4       9.4
#
#            WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  \
# Date                                                         ...
# 2017-06-21         SSE           37.0          W        SSE  ...         52.0
# 2017-06-22           W           30.0          W        ESE  ...         53.0
# 2017-06-23           W           24.0        WNW          N  ...         56.0
# 2017-06-24           W           43.0          W          W  ...         35.0
# 2017-06-25           W           35.0          W          W  ...         32.0
# ...

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  3334.000000  3335.000000  3331.000000  3286.000000  3321.000000
# mean     14.865057    23.002339     3.330231     5.187432     7.179374
# std       4.553641     4.494638     9.895172     2.777407     3.810886
# min       4.300000    11.700000     0.000000     0.000000     0.000000
# 25%      11.000000    19.600000     0.000000     3.200000     4.300000
# 50%      14.900000    22.800000     0.000000     4.800000     8.300000
# 75%      18.700000    26.000000     1.400000     7.000000    10.200000
# max      27.600000    45.800000   119.400000    18.400000    13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    2301.000000   3311.000000   3312.000000  3323.000000  3324.000000
# mean       41.761408     15.070674     19.335447    68.229010    54.699158
# std        13.007523      7.079724      7.482554    15.085355    16.293530
# ...

# %%
df.index.dtype
df_filter = df['2014-01-01':'2014-02-01']

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Using the matplotlib plotting mechanism built into Pandas
df.plot(y='MaxTemp', ax=ax)

# %%
sht2.pictures.add(fig, name='MyPlot', update=True)
# Out:
# <Picture 'MyPlot' in <Sheet [MyWorkbook_exercise_solutions.xlsx]Sheet1>>

# %% [markdown]
# # End of exercises
# The cell below is for setting the style of this document. It's not part of the exercises.

# %%
# Apply css theme to notebook
from IPython.display import HTML
HTML('<style>{}</style>'.format(open('../css/cowi.css').read()))
# Out:
# <style>
# /* div#notebook {
#  font-size: 13pt;
#  line-height: 120%;
#  color: #303030;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# } */
#
#
# body,
# div.body {
#  font-family: Roboto;
#  /* font-size: 16pt; */
#  color: #303030;
#  /* background-color: #d1b5b5; */
#  /* background: #8f4f4f; */
#  margin-right: 10px;
#  /* -webkit-font-smoothing: antialiased !important; */
# }
#
# /* Code inside HTML/Markdown */
# div.rendered_html code {
#     border-radius: 5px;
# }
#
# /* Output area from code cells */
# div.output_area pre {
#     /* font-size: 11pt !important; */
#     color: #303030;
# }
#
#
#
# /* HEADING 1 styles */
# h1 {
#     font-family: 'Roboto', 'Signika', sans-serif;
#     font-weight: ligher;
#     font-style: normal;
#     /* font-size: 20pt; */
#     width: 100%;
#     text-align: left;
#     color: #EE7631;
#     border-bottom: 1px solid rgba(238, 118, 49, 0.575);
#     padding-bottom: 6px;
# ...
